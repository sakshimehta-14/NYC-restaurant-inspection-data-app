# %% [markdown]
# ### Install the required libraries

# %%
# !pip install folium
# !pip install sodapy
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: folium in ./.venv/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in ./.venv/lib/python3.10/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in ./.venv/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (from folium) (2.28.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests->folium) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests->folium) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: sodapy in ./.venv/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: requests>=2.28.1 in ./.venv/lib/python3.10/site-packages (from sodapy) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests>=2.28.1->sodapy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests>=2.28.1->sodapy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests>=2.28.1->sodapy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests>=2.28.1->sodapy) (2022.12.7)
# Requirement already satisfied: sqlalchemy in ./.venv/lib/python3.10/site-packages (2.0.10)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.venv/lib/python3.10/site-packages (from sqlalchemy) (4.5.0)

# %% [markdown]
# #### Import the required packages in the jupyter notebook

# %%
import folium
from flask import Flask, render_template, request

import pandas as pd
from sodapy import Socrata
import psycopg2
from sqlalchemy import create_engine

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Creating a connection to PostgreSQL database to access our data tables

# %%
engine = create_engine('postgresql+psycopg2://postgres:123@localhost:5432/postgres_db')

# %%
results_df = pd.read_sql_query("""select * from restaurants r 
                                            inner join inspection_data i on r.camis = i.camis
                                            inner join borough b on r.boro = b.boro""",con=engine)
results_df.head(20)
# Out:
#        camis                              dba  boro building
# 0   40396492               ROYAL KING'S PIZZA     3     5211  \
# 1   50089288                      SPRING CAFE     1      153
# 2   50050467                   SYBIL'S BAKERY     4    15924
# 3   50087176                 K & L DAIRY FARM     4     7601
# 4   41145911                  WA LUNG KITCHEN     1      557
# 5   50072108                   UT47 MANHATTAN     1      358
# 6   50119865                            FONDA     1      139
# 7   50105559                LE PAIN QUOTIDIEN     1       60
# 8   41377310                         IL POETA     4     9804
# 9   41643622                   PEPPINOS PIZZA     2     4701
# 10  41575871          KAL BAKERY & RESTAURANT     3     3401
# 11  41696571                   THE EAGLE CAFE     1     1230
# 12  50090034                      WALSH'S PUB     4     6867
# 13  40721417  LOKI BAR & BENCHMARK RESTAURANT     3      304
# 14  41331356         DUNKIN',' BASKIN ROBBINS     4     2514
# 15  50093334                       JONGRO BBQ     4    15514
# 16  41387641                           BI WON     4    61-58
# 17  50050643                          NO BULL     3     1059
# 18  50088636             SANTA ANA RESTAURANT     3      187
# 19  50002749         SANTA ANA DELI & GROCERY     3      171
#
#                    street  zipcode phone cuisine_description   latitude
# 0                5 AVENUE  11220.0  None               Pizza  40.643850  \
# 1           CENTRE STREET  10013.0  None          Vegetarian  40.717770
# 2            HILLSIDE AVE  11432.0  None           Caribbean  40.707785
# 3                37TH AVE  11372.0  None          Sandwiches  40.749178
# 4            GRAND STREET  10002.0  None             Chinese  40.714033
# 5        WEST   47 STREET  10036.0  None          Coffee/Tea  40.761068
# 6            DUANE STREET  10013.0  None             Mexican  40.716312
# 7        WEST   65 STREET  10023.0  None              French  40.772461
# 8     METROPOLITAN AVENUE  11375.0  None             Italian  40.711019
# 9       WHITE PLAINS ROAD  10470.0  None               Pizza  40.903571
# 10          CHURCH AVENUE  11203.0  None              Creole  40.651015
# 11               6 AVENUE  10020.0  None            American  40.758970
# 12          FRESH POND RD  11385.0  None            American  40.703458
# 13               5 AVENUE  11215.0  None            American  40.673485
# 14               BROADWAY  11106.0  None            American  40.763297
# 15          ROOSEVELT AVE  11354.0  None              Korean  40.764020
# 16  SPRINGFIELD BOULEVARD  11364.0  None              Korean  40.748769
# 17        FLUSHING AVENUE  11237.0  None             Spanish  40.704247
# 18          IRVING AVENUE  11237.0  None             Mexican  40.701767
# 19          IRVING AVENUE  11237.0  None             Mexican  40.702193
#
#     longitude inspection_date                                inspection_type
# 0  -74.011603      2020-01-29               Cycle Inspection / Re-inspection  \
# 1  -74.000162      2023-03-07          Cycle Inspection / Initial Inspection
# 2  -73.802483      2022-04-04          Cycle Inspection / Initial Inspection
# 3  -73.889766      2022-07-12          Cycle Inspection / Initial Inspection
# 4  -73.980207      2022-08-30          Cycle Inspection / Initial Inspection
# 5  -73.989080      2019-05-21               Cycle Inspection / Re-inspection
# 6  -74.007770      2022-11-01  Pre-permit (Operational) / Initial Inspection
# 7  -73.980850      2022-04-20               Cycle Inspection / Re-inspection
# 8  -73.854473      2019-01-29          Cycle Inspection / Initial Inspection
# 9  -73.850277      2023-04-18          Cycle Inspection / Initial Inspection
# 10 -73.945565      2022-04-29          Cycle Inspection / Initial Inspection
# 11 -73.981089      2022-11-17               Cycle Inspection / Re-inspection
# 12 -73.895458      2019-05-09  Pre-permit (Operational) / Initial Inspection
# 13 -73.982718      2019-07-01               Cycle Inspection / Re-inspection
# 14 -73.928214      2022-03-14          Cycle Inspection / Initial Inspection
# 15 -73.809482      2019-09-23       Pre-permit (Operational) / Re-inspection
# 16 -73.756554      2022-03-01               Cycle Inspection / Re-inspection
# 17 -73.929944      2018-04-06   Inter-Agency Task Force / Initial Inspection
# 18 -73.919202      2023-04-01               Cycle Inspection / Re-inspection
# 19 -73.919956      2022-04-01        Cycle Inspection / Reopening Inspection
#
#                                              action violation_code
# 0   Violations were cited in the following area(s).            02B  \
# 1   Violations were cited in the following area(s).            10H
# 2   Violations were cited in the following area(s).            10H
# 3   Violations were cited in the following area(s).            09C
# 4   Violations were cited in the following area(s).            10H
# 5   Violations were cited in the following area(s).            06A
# 6   Violations were cited in the following area(s).            04H
# 7   Violations were cited in the following area(s).            06D
# 8   Violations were cited in the following area(s).            10H
# 9   Violations were cited in the following area(s).            04N
# 10  Violations were cited in the following area(s).            06C
# 11  Violations were cited in the following area(s).            10B
# 12  Violations were cited in the following area(s).            10B
# 13  Violations were cited in the following area(s).            06A
# 14  Violations were cited in the following area(s).            10I
# 15  Violations were cited in the following area(s).            06D
# 16  Violations were cited in the following area(s).            10F
# 17  Violations were cited in the following area(s).            05D
# 18  Violations were cited in the following area(s).            04L
# 19                Establishment re-opened by DOHMH.            10F
#
#                                 violation_description critical_flag  score
# 0          Hot food item not held at or above 140º F.      Critical   13.0  \
# 1   Single service article not provided.  Single s...  Not Critical   10.0
# 2   Proper sanitization not provided for utensil w...  Not Critical   30.0
# 3   Design, construction, materials used or mainte...  Not Critical    0.0
# 4   Single service article not provided.  Single s...  Not Critical   16.0
# 5   Personal cleanliness inadequate. Outer garment...      Critical   12.0
# 6   Raw, cooked or prepared food is adulterated, c...      Critical   35.0
# 7   Food contact surface not properly washed, rins...      Critical    5.0
# 8   Proper sanitization not provided for utensil w...  Not Critical   12.0
# 9   Filth flies or food/refuse/sewage associated w...      Critical   13.0
# 10  Food not protected from potential source of co...      Critical   32.0
# 11  Anti-siphonage or back-flow prevention device ...  Not Critical    7.0
# 12  Plumbing not properly installed or maintained;...  Not Critical    4.0
# 13  Personal cleanliness inadequate. Outer garment...      Critical   28.0
# 14  Single service item reused, improperly stored,...  Not Critical    7.0
# 15  Food contact surface not properly washed, rins...      Critical   11.0
# 16  Non-food contact surface improperly constructe...  Not Critical   11.0
# 17  Hand washing facility not provided in or near ...      Critical   18.0
# 18  Evidence of mice or live mice in establishment...      Critical   54.0
# 19  Non-food contact surface improperly constructe...  Not Critical    3.0
#
#    grade grade_date community_board council_district census_tract      bin
# 0      A 2020-01-29             307               38       010000  3013939  \
# 1      A 2023-03-07             101               01       003100  1002362
# 2   None        NaT             412               24       044602  4208981
# 3   None        NaT             403               25       028700  4029578
# 4   None        NaT             103               02       000202  1003219
# 5      A 2019-05-21             104               03       012700  1085022
# 6   None        NaT             101               01       003300  1001607
# 7      A 2022-04-20             107               06       014900  1086193
# 8      A 2019-01-29             406               29       064500  4095119
# 9      A 2023-04-18             212               11       041400  2071770
# 10  None        NaT             317               40       081600  3108686
# 11     A 2022-11-17             105               04       009600  1077287
# 12     A 2019-05-09             405               30       058100  4088114
# 13     C 2019-07-01             306               39       013500  3020782
# 14     A 2022-03-14             401               22       005300  4007157
# 15     A 2019-09-23             407               20       117100  4119346
# 16     A 2022-03-01             411               23       136700  4162215
# 17  None        NaT             301               34       045300  3070747
# 18     Z 2023-04-01             304               37       044300  3074526
# 19     Z 2022-04-01             304               37       044300  3325596
#
#            bbl   nta         record_date       name
# 0   3008080005  BK34 2023-04-24 06:00:08   BROOKLYN
# 1   1001970026  MN24 2023-04-24 06:00:08  MANHATTAN
# 2   4097650055  QN61 2023-04-24 06:00:08     QUEENS
# 3   4012760037  QN28 2023-04-24 06:00:08     QUEENS
# 4   1002660065  MN28 2023-04-24 06:00:08  MANHATTAN
# 5   1010370059  MN15 2023-04-24 06:00:08  MANHATTAN
# 6   1001477509  MN24 2023-04-24 06:00:08  MANHATTAN
# 7   1011170001  MN14 2023-04-24 06:00:08  MANHATTAN
# 8   4038930001  QN17 2023-04-24 06:00:08     QUEENS
# 9   2051070038  BX62 2023-04-24 06:00:08      BRONX
# 10  3048710040  BK91 2023-04-24 06:00:08   BROOKLYN
# 11  1012640005  MN17 2023-04-24 06:00:08  MANHATTAN
# 12  4036280052  QN20 2023-04-24 06:00:08     QUEENS
# 13  3009690045  BK37 2023-04-24 06:00:08   BROOKLYN
# 14  4005800022  QN70 2023-04-24 06:00:08     QUEENS
# 15  4052750132  QN51 2023-04-24 06:00:08     QUEENS
# 16  4076100040  QN42 2023-04-24 06:00:08     QUEENS
# 17  3030130032  BK77 2023-04-24 06:00:08   BROOKLYN
# 18  3032700008  BK77 2023-04-24 06:00:08   BROOKLYN
# 19  3032590008  BK77 2023-04-24 06:00:08   BROOKLYN

# %% [markdown]
# #### Implementing the interactive Flask application on a development server, visualizing the map and markers

# %%
app = Flask(__name__)

@app.route('/',methods=['GET', 'POST'])
def home():
    
    
    # create a new Folium map centered on New York City
    nymap = folium.Map(location=[40.7128, -74.0060], zoom_start=10, width=800, height=500)   
    
    if request.method == 'POST':
        # Get the name, zip, and borough
        lat = request.form['lat'].upper()
        lon = request.form['lon']
        bo = request.form['bor'].upper()
        
        if lon == "":
            if bo == "":
                filtered = results_df[(results_df['dba']==lat) & (results_df['critical_flag']=="Critical")]#[['latitude','longitude']].drop_duplicates()
            else:
                filtered = results_df[(results_df['name']==bo) & (results_df['dba']==lat) & (results_df['critical_flag']=="Critical")]#[['latitude','longitude']].drop_duplicates()
        # Create new markers and add to the map
        
#         filtered = results_df[(results_df['dba']=="DOMINO'S") & (results_df['critical_flag']=="Critical")][['latitude','longitude']].drop_duplicates()
        else:
            filtered = results_df[(results_df['dba']==lat) & (results_df['critical_flag']=="Critical") & (results_df['zipcode']==lon)]#[['latitude','longitude']].drop_duplicates()
        if len(filtered) > 0:
            # convert inspection_date to datetime
            filtered['inspection_date'] = pd.to_datetime(filtered['inspection_date'])

            # find the latest inspection date for each camis
            max_dates = filtered.groupby('camis')['inspection_date'].max()

            # create a boolean mask to identify rows with max inspection date
            mask = filtered.apply(lambda row: row['inspection_date'] == max_dates[row['camis']], axis=1)

            # filter the dataframe based on the mask
            filtered = filtered.loc[mask]
            filtered = filtered.groupby('camis').agg({'violation_code': ', '.join,'longitude':max,'latitude':max,'inspection_date':max}).reset_index()
            for i in range(len(filtered)):
                dat = filtered.inspection_date.iloc[i]
                folium.Marker([filtered.latitude.iloc[i],filtered.longitude.iloc[i]], popup=lat + ": " + filtered.violation_code.iloc[i] +
                              ". Last inspected: {}/{}/{}".format(dat.month,dat.day,dat.year)).add_to(nymap)

        # Convert the updated map to HTML and pass it to the template
        map_html = nymap.get_root().render()
        return render_template('index_0.html', map=map_html)
    # render the map in a Jinja2 template
    map_html = nymap.get_root().render()
    return render_template('index_0.html', map=map_html)


if __name__ == '__main__':
    app.run(port = 5002)

# consider adding no name only zip filter

# make it case insensitive
# make it so that partial match also works? (Not exact match)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5002
# Press CTRL+C to quit
# 127.0.0.1 - - [25/Apr/2023 21:58:13] "GET / HTTP/1.1" 200 -
# /var/folders/47/51ynn6fj00z9m6xp5vrp1zv40000gn/T/ipykernel_73777/3961605380.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['inspection_date'] = pd.to_datetime(filtered['inspection_date'])
# 127.0.0.1 - - [25/Apr/2023 21:58:16] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2023 21:58:23] "POST / HTTP/1.1" 200 -
# /var/folders/47/51ynn6fj00z9m6xp5vrp1zv40000gn/T/ipykernel_73777/3961605380.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['inspection_date'] = pd.to_datetime(filtered['inspection_date'])
# 127.0.0.1 - - [25/Apr/2023 21:58:29] "POST / HTTP/1.1" 200 -
# /var/folders/47/51ynn6fj00z9m6xp5vrp1zv40000gn/T/ipykernel_73777/3961605380.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['inspection_date'] = pd.to_datetime(filtered['inspection_date'])
# 127.0.0.1 - - [25/Apr/2023 21:58:37] "POST / HTTP/1.1" 200 -
# /var/folders/47/51ynn6fj00z9m6xp5vrp1zv40000gn/T/ipykernel_73777/3961605380.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['inspection_date'] = pd.to_datetime(filtered['inspection_date'])
# 127.0.0.1 - - [25/Apr/2023 21:58:48] "POST / HTTP/1.1" 200 -
